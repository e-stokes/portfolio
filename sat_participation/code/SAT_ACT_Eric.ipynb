# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('/Users/eric/dsi/Submissions/Projects/Project_1/data/sat_2017.csv')
act_2017 = pd.read_csv('/Users/eric/dsi/Submissions/Projects/Project_1/data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:The data represents the participation of each state and their respective scores in each area along with a total score for both the SAT and ACT tests.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Yes

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer:

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# ufo.loc[ufo['State'] == 'TX', ['City', 'Shape Reported']].head()

# %%
#code
# Fix Maryland SAT score
sat_2017.loc[20, 'Math'] = 524
sat_2017.loc[sat_2017['State'] == 'Maryland']
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# Fix Maryland ACT score for Science
act_2017.loc[act_2017['State'] == 'Maryland','Science'] = 23.2
act_2017.loc[act_2017['State'] == 'Maryland']
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2      23.6

# %%
#code
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: Composite looks as though it should be a float instead of an object.
#
# Participation also looks like it should be an integer instead of an object.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
# Use astype() to change from str to int/float
# Participation change to integer
# Change participation to 'Participation Percentage'
def convert_rate(data):
    try:
        return float(data.replace('%', ''))
    except:
        return data

def convert_wy(comp):
    try:
        return float(comp.replace('x',''))
    except:
        return comp
    
# Collaborated with Andrew Picard and Jeremy

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
# Fix Wyoming
act_2017['Composite'] = act_2017['Composite'].apply(convert_wy)

# %%
act_2017['Composite']
# Out:
# 0     21.0
# 1     19.2
# 2     19.8
# 3     19.7
# 4     19.4
# 5     22.8
# 6     20.8
# 7     25.2
# 8     24.1
# 9     24.2
# 10    19.8
# 11    21.4
# 12    19.0
# 13    22.3
# 14    21.4
# 15    22.6
# 16    21.9
# 17    21.7
# 18    20.0
# 19    19.5
# 20    24.3
# 21    23.6
# 22    25.4
# 23    24.1
# 24    21.5
# 25    18.6
# 26    20.4
# 27    20.3
# 28    21.4
# 29    17.8
# 30    25.5
# 31    23.9
# 32    19.7
# 33    24.2
# 34    19.1
# 35    20.3
# 36    22.0
# 37    19.4
# 38    21.8
# 39    23.7
# 40    24.0
# 41    18.7
# 42    21.8
# 43    19.8
# 44    20.7
# 45    20.3
# 46    23.6
# 47    23.8
# 48    21.9
# 49    20.4
# 50    20.5
# 51    20.2
# Name: Composite, dtype: float64

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
act_2017.tail()
# Out:
#             State Participation  English  Math  Reading  Science  Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5       23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0       21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5       20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9       20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6       20.2

# %%
#code
sat_2017['Participation'] = sat_2017['Participation'].apply(convert_rate)

# %%
sat_2017['Participation']
# Out:
# 0       5.0
# 1      38.0
# 2      30.0
# 3       3.0
# 4      53.0
# 5      11.0
# 6     100.0
# 7     100.0
# 8     100.0
# 9      83.0
# 10     61.0
# 11     55.0
# 12     93.0
# 13      9.0
# 14     63.0
# 15      2.0
# 16      4.0
# 17      4.0
# 18      4.0
# 19     95.0
# 20     69.0
# 21     76.0
# 22    100.0
# 23      3.0
# 24      2.0
# 25      3.0
# 26     10.0
# 27      3.0
# 28     26.0
# 29     96.0
# 30     70.0
# 31     11.0
# 32     67.0
# 33     49.0
# 34      2.0
# 35     12.0
# 36      7.0
# 37     43.0
# 38     65.0
# 39     71.0
# 40     50.0
# 41      3.0
# 42      5.0
# 43     62.0
# 44      3.0
# 45     60.0
# 46     65.0
# 47     64.0
# 48     14.0
# 49      3.0
# 50      3.0
# Name: Participation, dtype: float64

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
#code
act_2017['Participation'] = act_2017['Participation'].apply(convert_rate)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
print(sat_2017.dtypes)
print(act_2017.dtypes)
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_2017.rename(columns = {'State':'state',
                        'Participation':'participation_pct_sat_2017',
                        'Evidence-Based Reading and Writing':'reading_and_writing_sat_2017',
                        'Math':'math_sat_2017',
                        'Total':'total_sat_2017'
                        }, inplace = True)

# %%
act_2017.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act_2017.rename(columns = {'State':'state',
                           'Participation':'participation_pct_act_2017',
                           'English':'english_act_2017',
                           'Math':'math_act_2017',
                           'Reading':'reading_act_2017',
                           'Science':'science_act_2017',
                           'Composite':'composite_act_2017',
                          }, inplace = True)

# %%
sat_2017.head()
# Out:
#         state  participation_pct_sat_2017  reading_and_writing_sat_2017  \
# 0     Alabama                         5.0                           593
# 1      Alaska                        38.0                           547
# 2     Arizona                        30.0                           563
# 3    Arkansas                         3.0                           614
# 4  California                        53.0                           531
#
#    math_sat_2017  total_sat_2017
# 0            572            1165
# 1            533            1080
# 2            553            1116
# 3            594            1208
# 4            524            1055

# %%
act_2017.head()
# Out:
#       state  participation_pct_act_2017  english_act_2017  math_act_2017  \
# 0  National                        60.0              20.3           20.7
# 1   Alabama                       100.0              18.9           18.4
# 2    Alaska                        65.0              18.7           19.8
# 3   Arizona                        62.0              18.6           19.8
# 4  Arkansas                       100.0              18.9           19.0
#
#    reading_act_2017  science_act_2017  composite_act_2017
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4

# %%
#code

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|object|ACT/SAT|State Represented|
# |Participation|float|ACT/SAT|Percent of participation by state|
# |Reading & Writing|float|SAT|Reading and writing scores for SAT by state|
# |Math|float|ACT/SAT|Math scores for both SAT and ACT by state|
# |English|float|ACT|English scores for the ACT by state|
# |Reading|float|ACT|Reading comprehension scores for ACT by state|
# |Science|float|ACT|Science scores for ACT by state|
# |Composite|float|ACT|Average of all four sections|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
act_2017 = act_2017.drop(0, axis = 0)
act_2017.head()
# Out:
#         state  participation_pct_act_2017  english_act_2017  math_act_2017  \
# 1     Alabama                       100.0              18.9           18.4
# 2      Alaska                        65.0              18.7           19.8
# 3     Arizona                        62.0              18.6           19.8
# 4    Arkansas                       100.0              18.9           19.0
# 5  California                        31.0              22.5           22.7
#
#    reading_act_2017  science_act_2017  composite_act_2017
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4
# 5              23.1              22.2                22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
combined_2017 = pd.merge(act_2017, sat_2017, on = 'state')
combined_2017
# Out:
#                    state  participation_pct_act_2017  english_act_2017  \
# 0                Alabama                       100.0              18.9
# 1                 Alaska                        65.0              18.7
# 2                Arizona                        62.0              18.6
# 3               Arkansas                       100.0              18.9
# 4             California                        31.0              22.5
# 5               Colorado                       100.0              20.1
# 6            Connecticut                        31.0              25.5
# 7               Delaware                        18.0              24.1
# 8   District of Columbia                        32.0              24.4
# 9                Florida                        73.0              19.0
# 10               Georgia                        55.0              21.0
# 11                Hawaii                        90.0              17.8
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv('./combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
# Importing SAT 2018
sat_2018 = pd.read_csv('/Users/eric/dsi/Submissions/Projects/Project_1/data/sat_2018.csv')

# %%
# Importing ACT 2018
act_2018 = pd.read_csv('/Users/eric/dsi/Submissions/Projects/Project_1/data/act_2018.csv')

# %%
# Exploring ACT data for errors
act_2018
# Out:
#                    State Percent of Students Tested  Average Composite Score  \
# 0                Alabama                        100                     19.1
# 1                 Alaska                         33                     20.8
# 2                Arizona                         66                     19.2
# 3               Arkansas                        100                     19.4
# 4             California                         27                     22.7
# 5               Colorado                         30                     23.9
# 6            Connecticut                         26                     25.6
# 7               Delaware                         17                     23.2
# 8   District of Columbia                         32                     23.6
# 9                Florida                         66                     19.9
# 10               Georgia                         53                     21.4
# ...

# %%
# Exploring SAT data for errors
sat_2018
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
# Checking columns for ACT
act_2018.columns
# Out:
# Index(['State', 'Percent of Students Tested', 'Average Composite Score',
#        'Average English Score', 'Average Math Score', 'Average Reading Score',
#        'Average Science Score'],
#       dtype='object')

# %%
# Changing column titles for ACT
act_2018.rename(columns = {'State':'state',
                           'Percent of Students Tested':'pct_tested_act_2018',
                           'Average Composite Score':'avg_comp_act_2018',
                           'Average English Score':'avg_eng_act_2018',
                           'Average Math Score':'avg_math_act_2018',
                           'Average Reading Score':'avg_reading_act_2018',
                           'Average Science Score':'avg_science_act_2018'
                          }, inplace = True)

# %%
# Checking column changes
act_2018.head()
# Out:
#         state pct_tested_act_2018  avg_comp_act_2018  avg_eng_act_2018  \
# 0     Alabama                 100               19.1              18.9
# 1      Alaska                  33               20.8              19.8
# 2     Arizona                  66               19.2              18.2
# 3    Arkansas                 100               19.4              19.1
# 4  California                  27               22.7              22.5
#
#    avg_math_act_2018  avg_reading_act_2018  avg_science_act_2018
# 0               18.3                  19.6                  19.0
# 1               20.6                  21.6                  20.7
# 2               19.4                  19.5                  19.2
# 3               18.9                  19.7                  19.4
# 4               22.5                  23.0                  22.1

# %%
# checking sat columns
sat_2018.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
# changing sat column names
sat_2018.rename(columns = {'State':'state',
                           'Participation':'participation_pct_sat_2018',
                           'Evidence-Based Reading and Writing':'reading_and_writing_sat_2018',
                           'Math':'math_sat_2018',
                           'Total':'total_sat_2018',
                          }, inplace = True)

# %%
# checking column changes for sat
sat_2018.head()
# Out:
#         state participation_pct_sat_2018  reading_and_writing_sat_2018  \
# 0     Alabama                         6%                           595
# 1      Alaska                        43%                           562
# 2     Arizona                        29%                           577
# 3    Arkansas                         5%                           592
# 4  California                        60%                           540
#
#    math_sat_2018  total_sat_2018
# 0            571            1166
# 1            544            1106
# 2            572            1149
# 3            576            1169
# 4            536            1076

# %%
sat_2018.dtypes
# Out:
# state                           object
# participation_pct_sat_2018      object
# reading_and_writing_sat_2018     int64
# math_sat_2018                    int64
# total_sat_2018                   int64
# dtype: object

# %%
# changing SAT data types for participation pct 
sat_2018['participation_pct_sat_2018'] = sat_2018['participation_pct_sat_2018'].apply(convert_rate)

# %%
# checking sat datatypes
sat_2018.dtypes
# Out:
# state                            object
# participation_pct_sat_2018      float64
# reading_and_writing_sat_2018      int64
# math_sat_2018                     int64
# total_sat_2018                    int64
# dtype: object

# %%
act_2018.dtypes
# Out:
# state                    object
# pct_tested_act_2018      object
# avg_comp_act_2018       float64
# avg_eng_act_2018        float64
# avg_math_act_2018       float64
# avg_reading_act_2018    float64
# avg_science_act_2018    float64
# dtype: object

# %%
# Removing 'not given' in Louisiana

act_2018.loc[18, 'pct_tested_act_2018'] = '4'
act_2018.loc[act_2018['state'] == 'Louisiana']
# Out:
#         state pct_tested_act_2018  avg_comp_act_2018  avg_eng_act_2018  \
# 18  Louisiana                   4               19.2              19.0
#
#     avg_math_act_2018  avg_reading_act_2018  avg_science_act_2018
# 18               18.5                  19.6                  19.1

# %%
# removing 'not given' North Carolina
act_2018.loc[34, 'pct_tested_act_2018'] = '52'
act_2018.loc[act_2018['state'] == 'North Carolina']
# Out:
#              state pct_tested_act_2018  avg_comp_act_2018  avg_eng_act_2018  \
# 34  North Carolina                  52               19.1              18.0
#
#     avg_math_act_2018  avg_reading_act_2018  avg_science_act_2018
# 34               19.3                  19.5                  19.2

# %%
# removing 'not given' Oklahoma
act_2018.loc[37, 'pct_tested_act_2018'] = '8'
act_2018.loc[act_2018['state'] == 'Oklahoma']
# Out:
#        state pct_tested_act_2018  avg_comp_act_2018  avg_eng_act_2018  \
# 37  Oklahoma                   8               19.3              18.4
#
#     avg_math_act_2018  avg_reading_act_2018  avg_science_act_2018
# 37               18.8                  20.1                  19.4

# %%
# removing 'not given' for Pennsylvania
act_2018.loc[39, 'pct_tested_act_2018'] = '70'
act_2018.loc[act_2018['state'] == 'Pennsylvania']
# Out:
#            state pct_tested_act_2018  avg_comp_act_2018  avg_eng_act_2018  \
# 39  Pennsylvania                  70               23.5              23.3
#
#     avg_math_act_2018  avg_reading_act_2018  avg_science_act_2018
# 39               23.2                  24.0                  23.1

# %%
# dropping 'Natinoal' from act
act_2018 = act_2018.drop(27,axis = 0)

# %%
# changing ACT datatypes for pct_students_tested
act_2018['pct_tested_act_2018'] = act_2018['pct_tested_act_2018'].apply(convert_rate)

# %%
act_2018['pct_tested_act_2018']
# Out:
# 0     100.0
# 1      33.0
# 2      66.0
# 3     100.0
# 4      27.0
# 5      30.0
# 6      26.0
# 7      17.0
# 8      32.0
# 9      66.0
# 10     53.0
# 11     89.0
# 12     36.0
# 13     43.0
# 14     32.0
# 15     68.0
# 16     71.0
# 17    100.0
# 18      4.0
# 19      7.0
# 20     31.0
# 21     25.0
# 22     22.0
# 23     99.0
# 24    100.0
# 25    100.0
# 26    100.0
# 28    100.0
# 29    100.0
# 30     16.0
# 31     31.0
# 32     67.0
# 33     27.0
# 34     52.0
# 35     98.0
# 36    100.0
# 37      8.0
# 38     42.0
# 39     70.0
# 40     15.0
# 41    100.0
# 42     77.0
# 43    100.0
# 44     41.0
# 45    100.0
# 46     24.0
# 47     24.0
# 48     24.0
# 49     65.0
# 50    100.0
# 51    100.0
# Name: pct_tested_act_2018, dtype: float64

# %%
act_2018.dtypes
# Out:
# state                    object
# pct_tested_act_2018     float64
# avg_comp_act_2018       float64
# avg_eng_act_2018        float64
# avg_math_act_2018       float64
# avg_reading_act_2018    float64
# avg_science_act_2018    float64
# dtype: object

# %%
# checking drop of 'National'
act_2018
# Out:
#                    state  pct_tested_act_2018  avg_comp_act_2018  \
# 0                Alabama                100.0               19.1
# 1                 Alaska                 33.0               20.8
# 2                Arizona                 66.0               19.2
# 3               Arkansas                100.0               19.4
# 4             California                 27.0               22.7
# 5               Colorado                 30.0               23.9
# 6            Connecticut                 26.0               25.6
# 7               Delaware                 17.0               23.2
# 8   District of Columbia                 32.0               23.6
# 9                Florida                 66.0               19.9
# 10               Georgia                 53.0               21.4
# 11                Hawaii                 89.0               18.9
# 12                 Idaho                 36.0               22.3
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# merging 2018 ACT & SAT
combined_2018 = pd.merge(act_2018, sat_2018, on = 'state')
combined_2018
# Out:
#                    state  pct_tested_act_2018  avg_comp_act_2018  \
# 0                Alabama                100.0               19.1
# 1                 Alaska                 33.0               20.8
# 2                Arizona                 66.0               19.2
# 3               Arkansas                100.0               19.4
# 4             California                 27.0               22.7
# 5               Colorado                 30.0               23.9
# 6            Connecticut                 26.0               25.6
# 7               Delaware                 17.0               23.2
# 8   District of Columbia                 32.0               23.6
# 9                Florida                 66.0               19.9
# 10               Georgia                 53.0               21.4
# 11                Hawaii                 89.0               18.9
# 12                 Idaho                 36.0               22.3
# ...

# %%
# checking datatypes for combined 2018
combined_2018.dtypes
# Out:
# state                            object
# pct_tested_act_2018             float64
# avg_comp_act_2018               float64
# avg_eng_act_2018                float64
# avg_math_act_2018               float64
# avg_reading_act_2018            float64
# avg_science_act_2018            float64
# participation_pct_sat_2018      float64
# reading_and_writing_sat_2018      int64
# math_sat_2018                     int64
# total_sat_2018                    int64
# dtype: object

# %%
# Merging combined_2017 & combined_2018
combined_final = pd.concat([combined_2017, combined_2018], axis = 1)
combined_final
# Out:
#                    state  participation_pct_act_2017  english_act_2017  \
# 0                Alabama                       100.0              18.9
# 1                 Alaska                        65.0              18.7
# 2                Arizona                        62.0              18.6
# 3               Arkansas                       100.0              18.9
# 4             California                        31.0              22.5
# 5               Colorado                       100.0              20.1
# 6            Connecticut                        31.0              25.5
# 7               Delaware                        18.0              24.1
# 8   District of Columbia                        32.0              24.4
# 9                Florida                        73.0              19.0
# 10               Georgia                        55.0              21.0
# 11                Hawaii                        90.0              17.8
# ...

# %%
# saving final data
combined_final.to_csv('./final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
# used round() for sake of visual
combined_final.describe().round(3)
# Out:
#        participation_pct_act_2017  english_act_2017  math_act_2017  \
# count                      51.000            51.000         51.000
# mean                       65.255            20.931         21.182
# std                        32.141             2.354          1.982
# min                         8.000            16.300         18.000
# 25%                        31.000            19.000         19.400
# 50%                        69.000            20.700         20.900
# 75%                       100.000            23.300         23.100
# max                       100.000            25.500         25.300
#
#        reading_act_2017  science_act_2017  composite_act_2017  \
# count            51.000            51.000              51.000
# mean             22.014            21.451              21.520
# std               2.067             1.739               2.021
# min              18.100            18.200              17.800
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def stddev(data):
    mu = sum(data) / len(data)
    var = np.mean([(x - mu) ** 2 for x in data])
    
    return np.sqrt(var)

# Code idea from Stackoverflow, worked with Josh to fine tune function to work.

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
# dictionary comprehension / apply standard deviation function / assign output as 'sd'
# column name is a KEY / STD is Value

sd = {col: stddev(combined_final[col]) for col in combined_final.columns if col != 'state'}

# %%
# checking dictionary
sd
# Out:
# {'participation_pct_act_2017': 31.824175751231806,
#  'english_act_2017': 2.3304876369363368,
#  'math_act_2017': 1.9624620273436781,
#  'reading_act_2017': 2.046902931484265,
#  'science_act_2017': 1.7222161451443672,
#  'composite_act_2017': 2.0007860815819893,
#  'participation_pct_sat_2017': 34.929070766645076,
#  'reading_and_writing_sat_2017': 45.21697020437866,
#  'math_sat_2017': 46.65713364485504,
#  'total_sat_2017': 91.58351056778743,
#  'pct_tested_act_2018': 33.610805918778624,
#  'avg_comp_act_2018': 2.0855261815801143,
#  'avg_eng_act_2018': 2.4222536143202795,
#  'avg_math_act_2018': 2.0157072555557174,
#  'avg_reading_act_2018': 2.1458918845104216,
#  'avg_science_act_2018': 1.8516885484833538,
#  'participation_pct_sat_2018': 36.946619223539415,
#  'reading_and_writing_sat_2018': 47.03460978357609,
#  'math_sat_2018': 47.301945503783536,
#  'total_sat_2018': 93.22742384464432}

# %%
# Comparing SD results using Numpy
np.std(combined_final)
# Out:
# participation_pct_act_2017      31.824176
# english_act_2017                 2.330488
# math_act_2017                    1.962462
# reading_act_2017                 2.046903
# science_act_2017                 1.722216
# composite_act_2017               2.000786
# participation_pct_sat_2017      34.929071
# reading_and_writing_sat_2017    45.216970
# math_sat_2017                   46.657134
# total_sat_2017                  91.583511
# pct_tested_act_2018             33.610806
# avg_comp_act_2018                2.085526
# avg_eng_act_2018                 2.422254
# avg_math_act_2018                2.015707
# avg_reading_act_2018             2.145892
# avg_science_act_2018             1.851689
# participation_pct_sat_2018      36.946619
# reading_and_writing_sat_2018    47.034610
# math_sat_2018                   47.301946
# total_sat_2018                  93.227424
# dtype: float64

# %%
# Comparing SD results using describe
combined_final.describe()
# Out:
#        participation_pct_act_2017  english_act_2017  math_act_2017  \
# count                   51.000000         51.000000      51.000000
# mean                    65.254902         20.931373      21.182353
# std                     32.140842          2.353677       1.981989
# min                      8.000000         16.300000      18.000000
# 25%                     31.000000         19.000000      19.400000
# 50%                     69.000000         20.700000      20.900000
# 75%                    100.000000         23.300000      23.100000
# max                    100.000000         25.500000      25.300000
#
#        reading_act_2017  science_act_2017  composite_act_2017  \
# count         51.000000         51.000000           51.000000
# mean          22.013725         21.450980           21.519608
# std            2.067271          1.739353            2.020695
# min           18.100000         18.200000           17.800000
# ...

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# #### Answer:
# They do not exactly match up, they are within a decimal place of each other. The formula used is slightly different for Pandas and Numpy.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
combined_final[combined_final['participation_pct_sat_2017'] == combined_final['participation_pct_sat_2017'].max()][['state', 'participation_pct_act_2017']]
# Out:
#                    state                 state  participation_pct_act_2017
# 6            Connecticut           Connecticut                        31.0
# 7               Delaware              Delaware                        18.0
# 8   District of Columbia  District of Columbia                        32.0
# 22              Michigan              Michigan                        29.0

# %% [markdown]
# ### Max ACT 2017 Participation
#
# There are 17 states who had 100% participation for 2017.

# %%
combined_final[combined_final['participation_pct_act_2017'] == combined_final['participation_pct_act_2017'].min()][['state', 'participation_pct_act_2017']]
# Out:
#     state  state  participation_pct_act_2017
# 19  Maine  Maine                         8.0

# %% [markdown]
# ### Min ACT 2017 Participation
#
# Maine had the lowest Participation for the year of 2017.

# %%
combined_final[combined_final['participation_pct_sat_2017']==combined_final['participation_pct_sat_2017'].max()][['state', 'participation_pct_sat_2017']]
# Out:
#                    state                 state  participation_pct_sat_2017
# 6            Connecticut           Connecticut                       100.0
# 7               Delaware              Delaware                       100.0
# 8   District of Columbia  District of Columbia                       100.0
# 22              Michigan              Michigan                       100.0

# %% [markdown]
# ### Max SAT 2017 Participation
#
# There were four states that had 100% participation for the year of 2017.

# %%
combined_final[(combined_final['participation_pct_act_2017']==combined_final['participation_pct_act_2017'].max()) &
              (combined_final['participation_pct_act_2017']>50)][['state', 'participation_pct_act_2017','participation_pct_act_2017']]
# Out:
#              state           state  participation_pct_act_2017  \
# 0          Alabama         Alabama                       100.0
# 3         Arkansas        Arkansas                       100.0
# 5         Colorado        Colorado                       100.0
# 17        Kentucky        Kentucky                       100.0
# 18       Louisiana       Louisiana                       100.0
# 23       Minnesota       Minnesota                       100.0
# 24     Mississippi     Mississippi                       100.0
# 25        Missouri        Missouri                       100.0
# 26         Montana         Montana                       100.0
# 28          Nevada          Nevada                       100.0
# 33  North Carolina  North Carolina                       100.0
# 36        Oklahoma        Oklahoma                       100.0
# 40  South Carolina  South Carolina                       100.0
# 42       Tennessee       Tennessee                       100.0
# ...

# %% [markdown]
# ### Participation in ACT 2017 Above 50%
#
# Only states that have a 100% participation were above 50%, this meeans that the state required the testing.

# %%
combined_final[(combined_final['participation_pct_act_2017'] == combined_final['participation_pct_act_2017'].max()) &
              (combined_final['pct_tested_act_2018'] == 100)][['state', 'participation_pct_act_2017','pct_tested_act_2018']]
# Out:
#              state           state  participation_pct_act_2017  \
# 0          Alabama         Alabama                       100.0
# 3         Arkansas        Arkansas                       100.0
# 17        Kentucky        Kentucky                       100.0
# 24     Mississippi     Mississippi                       100.0
# 25        Missouri        Missouri                       100.0
# 26         Montana         Montana                       100.0
# 28          Nevada          Nevada                       100.0
# 40  South Carolina  South Carolina                       100.0
# 42       Tennessee       Tennessee                       100.0
# 44            Utah            Utah                       100.0
# 49       Wisconsin       Wisconsin                       100.0
# 50         Wyoming         Wyoming                       100.0
#
#     pct_tested_act_2018
# 0                 100.0
# 3                 100.0
# 17                100.0
# 24                100.0
# ...

# %% [markdown]
# ### Max Participation for 2017 & 2018 ACT
#
# There were 12 states that had 100% participation for both 2017 & 2018 ACT tests.

# %%
combined_final[(combined_final['participation_pct_act_2017'] == combined_final['participation_pct_act_2017'].max()) &
              (combined_final['participation_pct_sat_2018'] == 100)][['state', 'participation_pct_act_2017','participation_pct_sat_2018']]
# Out:
#       state     state  participation_pct_act_2017  participation_pct_sat_2018
# 5  Colorado  Colorado                       100.0                       100.0

# %% [markdown]
# ### Max Participation for 2017 & 2018 SAT
#
# Colorado was the only state that maintained 100% participation for both years.

# %%
combined_final[(combined_final['participation_pct_act_2017'] == combined_final['participation_pct_act_2017'].max()) &
              (combined_final['pct_tested_act_2018'])][['state', 'participation_pct_act_2017','pct_tested_act_2018']]
# Out:
#              state           state  participation_pct_act_2017  \
# 0          Alabama         Alabama                       100.0
# 3         Arkansas        Arkansas                       100.0
# 5         Colorado        Colorado                       100.0
# 17        Kentucky        Kentucky                       100.0
# 18       Louisiana       Louisiana                       100.0
# 23       Minnesota       Minnesota                       100.0
# 24     Mississippi     Mississippi                       100.0
# 25        Missouri        Missouri                       100.0
# 26         Montana         Montana                       100.0
# 28          Nevada          Nevada                       100.0
# 33  North Carolina  North Carolina                       100.0
# 36        Oklahoma        Oklahoma                       100.0
# 40  South Carolina  South Carolina                       100.0
# 42       Tennessee       Tennessee                       100.0
# ...

# %% [markdown]
# ### ACT Participation change
#
# 2 of the 5 states that dropped below 100% participation only maintained an above participation of 50%.

# %%
combined_final[(combined_final['participation_pct_act_2017'] == combined_final['participation_pct_act_2017']) &
              (combined_final['pct_tested_act_2018'] > 50)][['state', 'participation_pct_act_2017','pct_tested_act_2018']]
# Out:
#              state           state  participation_pct_act_2017  \
# 0          Alabama         Alabama                       100.0
# 2          Arizona         Arizona                        62.0
# 3         Arkansas        Arkansas                       100.0
# 9          Florida         Florida                        73.0
# 10         Georgia         Georgia                        55.0
# 11          Hawaii          Hawaii                        90.0
# 15            Iowa            Iowa                        67.0
# 16          Kansas          Kansas                        73.0
# 17        Kentucky        Kentucky                       100.0
# 23       Minnesota       Minnesota                       100.0
# 24     Mississippi     Mississippi                       100.0
# 25        Missouri        Missouri                       100.0
# 26         Montana         Montana                       100.0
# 27        Nebraska        Nebraska                        84.0
# ...

# %% [markdown]
# ### Participation above 50% on ACT
#
# Above are the states that had 50% above for both years.

# %%
combined_final[(combined_final['participation_pct_act_2017'] == combined_final['participation_pct_act_2017']) &
              (combined_final['pct_tested_act_2018'] > 50)][['state', 'participation_pct_act_2017','pct_tested_act_2018']]
# Out:
#              state           state  participation_pct_act_2017  \
# 0          Alabama         Alabama                       100.0
# 2          Arizona         Arizona                        62.0
# 3         Arkansas        Arkansas                       100.0
# 9          Florida         Florida                        73.0
# 10         Georgia         Georgia                        55.0
# 11          Hawaii          Hawaii                        90.0
# 15            Iowa            Iowa                        67.0
# 16          Kansas          Kansas                        73.0
# 17        Kentucky        Kentucky                       100.0
# 23       Minnesota       Minnesota                       100.0
# 24     Mississippi     Mississippi                       100.0
# 25        Missouri        Missouri                       100.0
# 26         Montana         Montana                       100.0
# 27        Nebraska        Nebraska                        84.0
# ...

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# importing Seaborn
import seaborn as sns

# %%
# figure size
plt.figure(figsize = (16,14))
# Mask
# mask = np.zeros_like(combined_final, dtype=np.bool)

mask = np.triu(np.ones_like(combined_final.corr()))


# Plot customizations:

plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# heatmap title
plt.title('Correlation of SAT and ACT (2017 & 2018)', fontsize = 30)

# heatmap
sns.heatmap(combined_final.corr(), annot = True, cmap = 'coolwarm', mask = mask);

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (10,6)) # You'll want to specify your figsize
    
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
    plt.tight_layout()
        
        # feel free to add more settings
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Code Math ACT 
subplot_histograms(combined_final, ['math_act_2017', 'avg_math_act_2018', 'math_sat_2017', 'avg_math_act_2018'],
                  ['Math Scores for ACT 2017', 'Math Scores for ACT 2018', 'Math Scores for SAT 2017', 'Math Scores for SAT 2018'],
                   ['Math Scores', 'Math Scores', 'Math Scores', 'Math Scores'])

# %%
# Histogram for Participation in SAT & ACT
subplot_histograms(combined_final, ['participation_pct_act_2017', 'pct_tested_act_2018', 'participation_pct_sat_2017', 'participation_pct_sat_2018' ],
                   ['Participation for ACT 2017','Participation for ACT 2018', 'Participation for SAT 2017', 'Participation for SAT 2018'],
                   ['Participation', 'Participation', 'Participation', 'Participation'])

# %%
combined_final.head()
# Out:
#         state  participation_pct_act_2017  english_act_2017  math_act_2017  \
# 0     Alabama                       100.0              18.9           18.4
# 1      Alaska                        65.0              18.7           19.8
# 2     Arizona                        62.0              18.6           19.8
# 3    Arkansas                       100.0              18.9           19.0
# 4  California                        31.0              22.5           22.7
#
#    reading_act_2017  science_act_2017  composite_act_2017  \
# 0              19.7              19.4                19.2
# 1              20.4              19.9                19.8
# 2              20.1              19.8                19.7
# 3              19.7              19.5                19.4
# 4              23.1              22.2                22.8
#
#    participation_pct_sat_2017  reading_and_writing_sat_2017  math_sat_2017  \
# 0                         5.0                           593            572
# ...

# %%
# Reading/Verbal ACT/SAT histogram 

subplot_histograms(combined_final, ['reading_act_2017', 'avg_reading_act_2018', 'reading_and_writing_sat_2017', 'reading_and_writing_sat_2018' ],
                   ['Reading for ACT 2017','Reading for ACT 2018', 'Reading for SAT 2017', 'Reading for SAT 2018'],
                   ['Reading Score', 'Reading Score', 'Reading Score', 'Reading Score'])

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
#     nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    
#     fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (10,6)) # You'll want to specify your figsize
    
#     ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    
#     for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
#         ax[i].hist(dataframe[column])
#         ax[i].set_title(list_of_titles[i])
#         ax[i].set_xlabel(list_of_xlabels[i])
#     plt.tight_layout()
        
#         # feel free to add more settings
#         # Set titles, labels, etc here for each subplot

# %%
# Function to make scatter plots
def scatter_plot(dataframe, x_value, y_value, title, x_label, y_label):
    plt.figure(figsize = (12,10))
    plt.scatter(dataframe[x_value], dataframe[y_value])
    plt.title(title, fontsize = 30)
    plt.xlabel(x_label, fontsize = 20)
    plt.ylabel(y_label, fontsize = 20)

# %%
# SAT vs. ACT math scores for 2017
scatter_plot(combined_final, 'math_sat_2017', 'math_act_2017', 'SAT & ACT Math Scores for 2017', 'Math SAT', 'Math ACT')

# %%
# SAT vs. ACT verbal/reading scores for 2017
scatter_plot(combined_final, 'reading_and_writing_sat_2017','reading_act_2017',
             'ACT & SAT Verbal & Reading Scores for 2017',
             'Reading & Writing SAT', 'Reading ACT'
            )

# %%
# SAT vs. ACT total/composite scores for 2017
scatter_plot(combined_final, 'total_sat_2017','composite_act_2017',
             'ACT & SAT Composite/Total for 2017',
             'Total SAT', 'Composite ACT'
            )

# %%
# Total scores for SAT 2017 vs. 2018
scatter_plot(combined_final, 'total_sat_2017','total_sat_2018',
             'Total Scores for SAT 2017 vs. 2018',
             'Total SAT 2017', 'Total SAT 2018'
            )

# %%
# Composite scores for ACT 2017 vs. 2018
scatter_plot(combined_final, 'composite_act_2017','avg_comp_act_2018',
             'Composite Scores for SAT 2017 vs. 2018',
             'Composite ACT 2017', 'Composite SAT 2018'
            )

# %%
combined_final.columns
# Out:
# Index(['state', 'participation_pct_act_2017', 'english_act_2017',
#        'math_act_2017', 'reading_act_2017', 'science_act_2017',
#        'composite_act_2017', 'participation_pct_sat_2017',
#        'reading_and_writing_sat_2017', 'math_sat_2017', 'total_sat_2017',
#        'state', 'pct_tested_act_2018', 'avg_comp_act_2018', 'avg_eng_act_2018',
#        'avg_math_act_2018', 'avg_reading_act_2018', 'avg_science_act_2018',
#        'participation_pct_sat_2018', 'reading_and_writing_sat_2018',
#        'math_sat_2018', 'total_sat_2018'],
#       dtype='object')

# %%
scatter_plot(combined_final, 'participation_pct_sat_2018','total_sat_2018',
             'Total Scores for SAT by Participation in 2018',
             'Paricipation', 'Score'
            )

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# This function needs work

# Box Function:
# def box_plot(dataframe, x_value, y_value):
#     plt.figure(figsize = (14, 12))
#     sns.boxplot(x = x_value, y = y_value, data = dataframe)

# %%
# Code Comparing Total SAT Scores for 2017 & 2018
plt.figure(figsize = (10,8))
plt.title('Total SAT Scores for 2017 vs. 2018', fontsize = 30)
sns.boxplot(data = [combined_final['total_sat_2017'], combined_final['total_sat_2018']],
            orient = 'v', width = .3,).set_xticklabels(['Total SAT 2017', 'Total SAT 2018']);

# %%
# Boxplot for ACT 2017 vs 2018 Composite Scores
plt.figure(figsize = (10,8))
plt.title('Composite Scores for ACT 2017 vs. 2018', fontsize = 25)
sns.boxplot(data = [combined_final['composite_act_2017'], combined_final['avg_comp_act_2018']],
            orient = 'v', width = .3).set_xticklabels(['Composite for ACT 2017', 'Composite for ACT 2018']);

# %%
# Boxplot Participation between 2017 & 2018 for both SAT & ACT
plt.figure(figsize = (10,8))
plt.title('Participation of SAT & ACT 2017 vs. 2018', fontsize = 25)
sns.boxplot(data = [combined_final['participation_pct_sat_2017'], combined_final['participation_pct_act_2017'],
                   combined_final['participation_pct_sat_2018'],combined_final['pct_tested_act_2018']],
            orient = 'h', width = .5,).set_yticklabels(['Participation SAT 2017', 'Participation ACT 2017',
                                                       'Participation SAT 2018', 'Participation ACT 2018']);

# %%
# Reading scores for SAT between 2017 vs 2018
plt.figure(figsize = (10,8))
plt.title('Reading & Writing of SAT 2017 vs. 2018', fontsize = 25)
sns.boxplot(data = [combined_final['reading_and_writing_sat_2017'], combined_final['reading_and_writing_sat_2018']],
            orient = 'h', width = .3,).set_yticklabels(['Reading & Writing SAT 2017', 'Reading & Writing SAT 2018']);

# %%
combined_final.columns
# Out:
# Index(['state', 'participation_pct_act_2017', 'english_act_2017',
#        'math_act_2017', 'reading_act_2017', 'science_act_2017',
#        'composite_act_2017', 'participation_pct_sat_2017',
#        'reading_and_writing_sat_2017', 'math_sat_2017', 'total_sat_2017',
#        'state', 'pct_tested_act_2018', 'avg_comp_act_2018', 'avg_eng_act_2018',
#        'avg_math_act_2018', 'avg_reading_act_2018', 'avg_science_act_2018',
#        'participation_pct_sat_2018', 'reading_and_writing_sat_2018',
#        'math_sat_2018', 'total_sat_2018'],
#       dtype='object')

# %%
# Reading scores for ACT for 2017 vs 2018
plt.figure(figsize = (10,8))
plt.title('Reading Scores of ACT 2017 vs. 2018', fontsize = 25)
sns.boxplot(data = [combined_final['reading_act_2017'], combined_final['avg_reading_act_2018']],
            orient = 'h', width = .3,).set_yticklabels(['Score ACT 2017', 'S ACT 2018']);

# %%
# ACT Comparisons by Category 2017
plt.figure(figsize = (10,8))
plt.title('ACT Comparisons by Category for 2017', fontsize = 25)
sns.boxplot(data = [combined_final['english_act_2017'], combined_final['math_act_2017'],
                   combined_final['reading_act_2017'],combined_final['science_act_2017']],
            orient = 'v', width = .6).set_xticklabels(['English', 'Math',
                                                       'Reading', 'Science']);

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# https://public.tableau.com/profile/eric8719#!/vizhome/SAT_ACT_visualization/Sheet1

# %% [markdown]
# # Outside Resources
# States that require SAT: https://blog.prepscholar.com/which-states-require-the-sat

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
sat_2018.describe()

# %%
combined_final.agg(['mean', 'median'])

# %% [markdown]
# Answers: The mean and median are equal and would line up as a normally distributed distribution for the ACT reading in 2017.
#
# We can also look at the other distributions in 2018 and conclue that they are normally distributed given that they also have an equal mean, median, and mode.
#
# Participation however is left skewed in 2018 for the SAT compared to a normal distribution in 2017.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer: Yes they are normally distributed.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: I think there is more data that could be helpful, data regarding districts, and other local information to help draw a more precise conclusion. Having data and populations, can cause our scores to become more normally distributed if we base it off the size of population participating as a whole. These are after all averages which are dispersed over the population.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: No, one is an actual score vs an average percentage. There will be differences within those alone.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Wiscounsin had a 100% participation in the ACT test and only 4% participation in the SAT, yet they had one of the highest SAT scores at 1294 as the average score. This would be a good state of focus as it already also has 2 states bordering that have 100% participation in the SAT (Michigan & Illionis). Also according to the link below, some colleges are making the tests optional, a good chance to push the need for the test to individuals.
#
# https://www.wpr.org/marquette-university-no-longer-requiring-act-sat-scores-admission
#
#
# Kentucy also had an average score of 999 for the SAT with 28% of participation, on average based on the scores required by the University of Kentucky, they would need to score 1150 - 1390 and be in the top 32 percentile to qualify for college education. This average would need to trend higher to meet the expectation.
# https://www.collegesimply.com/colleges/kentucky/university-of-kentucky/admission/
#
#
# The state of Tennessee requires a student to take either SAT or ACT and would be a good attraction for a SAT campaign to grow its participation and growth within the state.
# https://blog.prepscholar.com/which-states-require-the-sat

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Based on my observations, the state of Wisconsin would be a good start-up state. With it's high average score of 1294, and low participation rate, starting a campaign to sweep the ACT requirement from the state would be capable given a strong marketing campagin coupled with an adjustment in the testing structure and curriculum. Spending money to adjust the package of the SAT to be a complete testing package instead of having to pay for each section and then marketing our newly packaged test with a more meaningful curriculum and drive to show participants that the test has value for their future beyond just college acceptance. Marketing with flyers, T.V adervtisements, State, and University support drive students to partake in the SAT alone. To become the standard, we must be the standard with the SAT leading and innovating the future of testing.
